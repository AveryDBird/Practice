# %%
strE = "hello"
print(len(strE))
print(max(strE))
print(min(strE))
# Out:
# 5
# o
# e

# %%
inte=3
print(strE+str(inte))
# Out:
# hello3

# %%
for i in range (1,15,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13

# %%
print(f"{inte}")
# Out:
# 3

# %%
show_expected_result = False
show_hints = False

def find_largest(numbers):
    longest = 0
    for strs in numbers:
        if len(strs) > longest:
            longest = len(strs)
    return longest

# %%
sample_file = open("textfile.txt","w+")
sample_file.write("testing file writing")
sample_file.close()

# %%
sample_file = open("textfile.txt","a")
sample_file.write("testing appeading to file")
sample_file.close()

# %% [markdown]
# reading files

# %%
sample_file = open("textfile.txt","r")
if sample_file.mode == "r":
  print(sample_file.read())
  file_line = sample_file.readline()
  for line in file_line:
    print(line)
  print(file_line)
sample_file.close()
# Out:
# testing file writingtesting appeading to filetesting appeading to file

# %%
import os
from os import *
import time
from datetime import datetime

print (os.name)
print("item exsits", path.exists("textfile.txt"))
print("it is located", path.realpath("textfile.txt"))
print("it is a file", path.isfile("textfile.txt"))
print("last modified", path.getmtime("textfile.txt"))
print("it is a directory", path.isdir("textfile.txt"))
print("it has been modified" , time.ctime(path.getmtime("textfile.txt")))
timeago = time.ctime(path.getmtime("textfile.txt"))
lastmod = datetime.now() - datetime.fromtimestamp(path.getmtime("textfile.txt"))
print("was last mod", lastmod)
# Out:
# posix
# item exsits True
# it is located /content/textfile.txt
# it is a file True
# last modified 1787847349.9609814
# it is a directory False
# it has been modified Thu Aug 27 16:15:49 2026
# was last mod 0:15:19.480876

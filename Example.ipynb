# %%
import pandas as pd
df = pd.read_csv('NewCoderSurvey.csv')
#df.head()
df.columns
# Out:
# /tmp/ipykernel_1159/1841981746.py:2: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NewCoderSurvey.csv')
# Index(['Timestamp', '1. What is your biggest reason for learning to code?',
#        '2. What methods have you used to learn about coding? Please select all that apply.',
#        '3. Which online learning resources have you found helpful? Please select all that apply.',
#        '4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.',
#        '5. If you have listened to coding-related podcasts before, which ones have you found helpful? Please select all that apply.',
#        '6. If you have watched coding-related YouTube videos before, which channels have you found helpful? Please select all that apply.',
#        '7. About how many hours do you spend learning each week?',
# ...

# %%
# !pip install itables
from itables import init_notebook_mode
from itables import show
init_notebook_mode(all_interactive=True)
show(df)
# Out:
# ...
# <script type="module">
#     import { set_or_remove_dark_class } from 'https://www.unpkg.com/dt_for_itables/dt_bundle.js';
#     set_or_remove_dark_class();
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d3c95493_ba65_4ee0_9dde_df2c8dadefa1" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
# ...

# %%
#for each column starting in the second column , show the number of unique enteries
colums_to_check = df.columns[1:]
for column in colums_to_check:
  unique_count = df[column].nunique()
  print(f"Number of unique values in column '{column}': {unique_count}")
# Out:
# Number of unique values in column '1. What is your biggest reason for learning to code?': 794
# Number of unique values in column '2. What methods have you used to learn about coding? Please select all that apply.': 1736
# Number of unique values in column '3. Which online learning resources have you found helpful? Please select all that apply.': 5453
# Number of unique values in column '4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.': 606
# Number of unique values in column '5. If you have listened to coding-related podcasts before, which ones have you found helpful? Please select all that apply.': 858
# Number of unique values in column '6. If you have watched coding-related YouTube videos before, which channels have you found helpful? Please select all that apply.': 4898
# Number of unique values in column '7. About how many hours do you spend learning each week?': 114
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print("number of rows:", df.shape[0])
print("number of columns:", df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2002/1997382674.py in <cell line: 0>()
# ----> 1 print("number of rows:", df.shape[0])
#       2 print("number of columns:", df.shape[1])
#
# NameError: name 'df' is not defined

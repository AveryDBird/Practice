# %%
sample_file = open("textfile.txt","w+")

# %%
import os
from os import path
import shutil
from zipfile import ZipFile

if path.exists("newfile.txt"):
  src = path.realpath("newfile.txt")

  #dst = src + ".bak"

  #shutil.copy(src,dst)
  #os.rename("textfile.txt", "newfile.txt")

  root_dir , tail = path.split(src)
  shutil.make_archive("archive", "zip", root_dir)

  with ZipFile("testzip.zip", "w") as newzip:
    newzip.write("newfile.txt")
    newzip.write("textfile.txt.bak")

  os.remove("newfile.txt")
  os.remove("textfile.txt.bak")
  os.remove("archive.zip")
  os.remove("testzip.zip")
if path.exists("textfile.txt"):
  os.remove("textfile.txt")
else:
  print("The file does not exist")
  sample_file.write("Hello World\n")
  sample_file.write("This is our new text file\n")
  sample_file.write("and this is another line\n")
  sample_file.write("Why? Because we can.\n")
  sample_file.close()
  sample_file = open("textfile.txt","r")
  if sample_file.mode == 'r':
    contents = sample_file.read()
    print(contents)
  sample_file.close()
  sample_file = open("textfile.txt","r")
  if sample_file.mode == 'r':
    fl = sample_file.readlines()
    for x in fl:
      print(x)
  sample_file.close()
  sample_file = open("textfile.txt","r")
  if sample_file.mode == 'r':
    fl = sample_file.readline()
    print(fl)
  sample_file.close()
  sample_file = open("textfile.txt","r")
  if sample_file.mode == 'r':
    fl = sample_file.readline()
    while fl:
      print(fl)
      fl = sample_file.readline()
      sample_file.close()

# %%
import os
from os import path

show_expected_result = False
show_hints = False

def file_info():
    filesize = 0
    depscontent = os.listdir("deps")
    for i in depscontent:
        if i.endswith(".txt"):
            full_path = os.path.join("deps",i)
            filesize = filesize + os.path.getsize(full_path)
    return filesize

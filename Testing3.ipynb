# %%
print ("hello world")
# Out:
# hello world

# %%
mylist = [0,1,"two",3.2,False]
print(len(mylist))
# Out:
# 5

# %%
print (mylist[-2])
# Out:
# 3.2

# %%
mystr = "thisisstring"
print(mystr[2])
# Out:
# i

# %%
print(mylist[1:4:2])
print(mylist[::-1])
#can also use that to reverse string

# %%
#tuples are imutable
mytuple=(0,1,2,"three")

# %%
myset = {1,2,3,4}
#can only contain unique values
#cant use indexes o sets

# %%
print(1 in mylist)
print(3 in mytuple)
print (5 in myset)

# %%
#dictionary python
mydict = {
    "one" :1,
    "two" :2,
    "three" :3,
    4 : "four",
    4.5 : ["four","point", "five"]

}
print(mydict)
mydict["seven"] =7
print(mydict)
print(mydict["three"])
if ("two" in mydict):
  print(mydict.keys())
# Out:
# {'one': 1, 'two': 2, 'three': 3, 4: 'four', 4.5: ['four', 'point', 'five']}
# {'one': 1, 'two': 2, 'three': 3, 4: 'four', 4.5: ['four', 'point', 'five'], 'seven': 7}
# 3
# dict_keys(['one', 'two', 'three', 4, 4.5, 'seven'])

# %%
#can also do .values
for key, val in mydict.items():
  print(key,val)
# Out:
# one 1
# two 2
# three 3
# 4 four
# 4.5 ['four', 'point', 'five']
# seven 7

# %%
x,y = 10,100
if x < y:
  print("x is less than y")
elif x<y:
  print("x is greater than y")
else:
  print("x is equal to y")
# Out:
# x is less than y

# %%
result = "x is less than y" if(x<y) else "x is greater or eaqual"
print(result)
# Out:
# x is less than y

# %%
x=0
while x<5:
  print(x)
  x = x+1
answer = input("should I stop")
while answer != "yes":
  print(answer)
  answer = input("should I stop")
# Out:
# 0
# 1
# 2
# 3
# 4
# should I stopno
# no
# should I stopno
# no
# should I stopyes

# %%
days = ["mon","tue"]
for d in days:
  print(d)
# Out:
# mon
# tue

# %% [markdown]
# <a href="https://colab.research.google.com/github/AveryDBird/Practice/blob/main/Testing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world")
# Out:
# hello world

# %%
mylist = [0,1,"two",3.2,False]
print(len(mylist))
# Out:
# 5

# %%
print (mylist[-2])
# Out:
# 3.2

# %%
mystr = "thisisstring"
print(mystr[2])
# Out:
# i

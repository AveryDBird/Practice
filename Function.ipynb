# %%
def hello_func():
  print("hellow world")
  name = input("what is your name")
  print("nice to meet you, "+ name)
hello_func()
# Out:
# hellow world
# what is your nameava
# nice to meet you, ava

# %%
def hello_func(greeting, name = None):
  print("hellow world")
  if name ==None:
    name = input("what is your name ")
  print(greeting , name)
hello_func("hey whats up")
hello_func(name = "joe", greeting = "Nice to meet you")
# Out:
# hellow world
# what is your name jow
# hey whats up jow
# hellow world
# Nice to meet you joe

# %%
def cube(x):
  return x*x*x
result = cube(3)
print(result)
# Out:
# 27

# %%
def multi_add(*args):
  result = 0
  for x in args:
    result = result + x
  return result

print(multi_add(4,5,10,10))
# Out:
# 29

# %%
#challange  Python code below
# Use print("messages...") to debug your solution.

show_expected_result = False
show_hints = False

def count_numbers(which, numbers):
    evencounter = 0
    oddcounter = 0
    if which =="even" or which =="odd":
        for num in numbers:
            if num % 2 ==0:
                evencounter = evencounter +1
            else:
                oddcounter = oddcounter +1
        if which =="even":
            return evencounter
        else:
            return oddcounter


    else:
        return -1
    # Your code goes here
    return -1
